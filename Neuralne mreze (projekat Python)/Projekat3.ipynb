# %% [markdown]
# **Ucitavanje slika sa google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
main_path_trainval = './drive/MyDrive/Neuralne mreze/Ultimativni_folder/Train_set'
main_path_test = './drive/MyDrive/Neuralne mreze/Ultimativni_folder/Test_set'
img_size = (64, 64)
batch_size = 64

# %% [markdown]
# **Podela lika na Train Val Test skupove**

# %%
from keras.utils import image_dataset_from_directory
Xtrain = image_dataset_from_directory(main_path_trainval,
      subset='training',
      validation_split=0.2,
      image_size=img_size,
      batch_size=batch_size,
      shuffle = True,
      seed=123)
Xval = image_dataset_from_directory(main_path_trainval,
      subset='validation',
      validation_split=0.2,
      image_size=img_size,
      batch_size=batch_size,
      shuffle = True,
      seed=123)
Xtest = image_dataset_from_directory(main_path_test,     
      image_size=img_size,
      batch_size=batch_size)
# Out:
# Found 2500 files belonging to 5 classes.
# Using 2000 files for training.
# Found 2500 files belonging to 5 classes.
# Using 500 files for validation.
# Found 500 files belonging to 5 classes.

# %%
classes1 = Xtrain.class_names
print(classes1)
print(len(classes1))
classes2 = Xval.class_names
print(classes2)
print(len(classes2))
classes3 = Xtest.class_names
print(classes3)
print(len(classes3))
# Out:
# ['V', 'W', 'X', 'Y', 'Z']
# 5
# ['V', 'W', 'X', 'Y', 'Z']
# 5
# ['V', 'W', 'X', 'Y', 'Z']
# 5

# %% [markdown]
# **Raspodela slika po klasama**

# %%
import os
X = [ 'V', 'W', 'X', 'Y', 'Z'];
for i in X:
    myPath = os.path.abspath('./drive/MyDrive/Neuralne mreze/Ultimativni_folder/Train_set/'+i)
    num = 0
    items = os.listdir(myPath)
    for item in items:
        if os.path.isfile(os.path.join(myPath, item)):
            num = num + 1  
    print(f'Broj slika za clasu: {i} je:  {num}')
# Out:
# Broj slika za clasu: V je:  500
# Broj slika za clasu: W je:  500
# Broj slika za clasu: X je:  500
# Broj slika za clasu: Y je:  500
# Broj slika za clasu: Z je:  500

# %% [markdown]
# **Primer slike iz svake klase**

# %%
N = 5
plt.figure()
for img, lab in Xtrain.take(1):
  for i in range(N):
      plt.subplot(1, N, i+1)
      plt.imshow(img[i].numpy().astype('uint8'))
      plt.title(classes1[lab[i]])
      plt.axis('off')

# %% [markdown]
# **Transformacije slike**

# %%
data = Xtrain.map(lambda x,y: (x*2, y))
#data = Xtrain.map(lambda x,y: ((x - min(x))/(max(x) - min(x)), y))

N = 5
plt.figure()
for img, lab in data.take(1):
  for i in range(N):
      plt.subplot(1, N, i+1)
      plt.imshow(img[i].numpy().astype('uint8'))
      plt.title(classes1[lab[i]])
      plt.axis('off')

# %% [markdown]
# **Augmentacija**

# %%
from keras import layers
from keras import Sequential
data_augmentation = Sequential(
 [
 layers.RandomFlip("horizontal", input_shape=(img_size[0], img_size[1], 3)),
 layers.RandomRotation(0.25),
 layers.RandomZoom(0.1),
 ]
)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %% [markdown]
# **Efekat augmentacije**

# %%
N = 5
plt.figure()
for img, lab in Xtrain.take(1):
    plt.title(classes1[lab[0]])
    for i in range(N):
        aug_img = data_augmentation(img)
        plt.subplot(1, N, i+1)
        plt.imshow(aug_img[0].numpy().astype('uint8'))
        plt.title(classes1[lab[i]])
        plt.axis('off')
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
pip install scikeras
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting scikeras
#   Downloading scikeras-0.10.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from scikeras) (1.0.2)
# Requirement already satisfied: packaging>=0.21 in /usr/local/lib/python3.8/dist-packages (from scikeras) (23.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=1.0.0->scikeras) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.7.3)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=1.0.0->scikeras) (1.21.6)
# Installing collected packages: scikeras
# Successfully installed scikeras-0.10.0

# %% [markdown]
# **Nasa Mreza**

# %%
from keras.regularizers import l2
from keras import Sequential
from keras import layers
from keras.optimizers import Adam
from keras.losses import SparseCategoricalCrossentropy 
from matplotlib import pyplot
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import GridSearchCV
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import KFold
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import GridSearchCV
num_classes = len(classes1)


def make_model(drop = 0.2, llr = 0.001, ll2 = 0.01):
    model = Sequential([
    data_augmentation,
    layers.Rescaling(1./255, input_shape=(64, 64, 3)),
    layers.Conv2D(16, 3, padding='same', activation='relu',kernel_regularizer=l2(ll2)),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding='same', activation='relu', kernel_regularizer=l2(ll2)),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding='same', activation='relu', kernel_regularizer=l2(0.01)),
    layers.Conv2D(64, 3, padding='same', activation='relu', kernel_regularizer=l2(0.01)),
    layers.MaxPooling2D(),
    layers.Dropout(drop),
    layers.Flatten(),
    layers.Dense(128, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(num_classes, activation='softmax')
    ])
    model.summary()
    model.compile(Adam(learning_rate=llr),
              loss=SparseCategoricalCrossentropy(),
              metrics='accuracy')
    return model

# %%
pip install scikeras

# %% [markdown]
# **Ucenje sa 60 epoha**

# %%
model1 = make_model(0.25)
history1 = model1.fit(Xtrain,
 epochs=60,
 validation_data=Xval,
 verbose=0)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Model: "sequential_162"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 64, 64, 3)         0
#
#  rescaling_163 (Rescaling)   (None, 64, 64, 3)         0
#
#  conv2d_800 (Conv2D)         (None, 64, 64, 16)        448
#
#  max_pooling2d_480 (MaxPooli  (None, 32, 32, 16)       0
#  ng2D)
#
#  conv2d_801 (Conv2D)         (None, 32, 32, 32)        4640
#
#  conv2d_802 (Conv2D)         (None, 32, 32, 32)        9248
#
#  max_pooling2d_481 (MaxPooli  (None, 16, 16, 32)       0
#  ng2D)
#
#  conv2d_803 (Conv2D)         (None, 16, 16, 64)        18496
#
#  conv2d_804 (Conv2D)         (None, 16, 16, 64)        36928
#
#  max_pooling2d_482 (MaxPooli  (None, 8, 8, 64)         0
#  ng2D)
#
#  dropout_160 (Dropout)       (None, 8, 8, 64)          0
#
#  flatten_160 (Flatten)       (None, 4096)              0
#
#  dense_480 (Dense)           (None, 128)               524416
#
#  dense_481 (Dense)           (None, 128)               16512
#
#  dense_482 (Dense)           (None, 5)                 645
#
# =================================================================
# Total params: 611,333
# Trainable params: 611,333
# Non-trainable params: 0
# _________________________________________________________________
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
acc = history1.history['accuracy']
val_acc = history1.history['val_accuracy']
loss = history1.history['loss']
val_loss = history1.history['val_loss']
plt.figure()
plt.subplot(121)
plt.plot(acc)
plt.plot(val_acc)
plt.title('Accuracy')
plt.subplot(122)
plt.plot(loss)
plt.plot(val_loss)
plt.title('Loss')
plt.show()

# %%
labels = np.array([])
pred = np.array([])
for img, lab in Xtest:
    labels = np.append(labels, lab)
    pred = np.append(pred, np.argmax(model1.predict(img, verbose=0), axis=1))

# %%
from sklearn.metrics import accuracy_score
print('Tačnost modela na test skupu je: ' + str(100*accuracy_score(labels, pred)) + '%')
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(labels, pred, normalize='true')
cmDisplay = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes1)
cmDisplay.plot()
plt.show()
# Out:
# Tačnost modela na test skupu je: 55.60000000000001%

# %% [markdown]
# **Ucenje sa 100 epoha drop = 0.1, lr = 0.001, l2 = 0.01**

# %%
model2 = make_model(0.1, 0.001, 0.01)
history2 = model2.fit(Xtrain,
 epochs=100,
 validation_data=Xval,
 verbose=1)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 64, 64, 3)         0
#
#  rescaling (Rescaling)       (None, 64, 64, 3)         0
#
#  conv2d (Conv2D)             (None, 64, 64, 16)        448
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        4640
#
#  conv2d_2 (Conv2D)           (None, 32, 32, 32)        9248
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        18496
#
#  conv2d_4 (Conv2D)           (None, 16, 16, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 64)         0
#  2D)
#
#  dropout (Dropout)           (None, 8, 8, 64)          0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 128)               524416
#
#  dense_1 (Dense)             (None, 128)               16512
#
#  dense_2 (Dense)             (None, 5)                 645
#
# =================================================================
# Total params: 611,333
# Trainable params: 611,333
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 13/32 [===========>..................] - ETA: 1:49 - loss: 2.9852 - accuracy: 0.1815

# %%
acc = history2.history['accuracy']
val_acc = history2.history['val_accuracy']
loss = history2.history['loss']
val_loss = history2.history['val_loss']
plt.figure()
plt.subplot(121)
plt.plot(acc)
plt.plot(val_acc)
plt.title('Accuracy')
plt.subplot(122)
plt.plot(loss)
plt.plot(val_loss)
plt.title('Loss')
plt.show()

# %%
labels = np.array([])
pred = np.array([])
for img, lab in Xtest:
    labels = np.append(labels, lab)
    pred = np.append(pred, np.argmax(model2.predict(img, verbose=0), axis=1))

# %%
from sklearn.metrics import accuracy_score
print('Tačnost modela na test skupu je: ' + str(100*accuracy_score(labels, pred)) + '%')
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(labels, pred, normalize='true')
cmDisplay = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes1)
cmDisplay.plot()
plt.show()
# Out:
# Tačnost modela na test skupu je: 62.2%

# %% [markdown]
# **Ucenje sa 100 epoha lr = 0.0001, dropout = 0.2**

# %%
model3 = make_model(0.1, 0.0001, 0.01)
history3 = model3.fit(Xtrain,
 epochs=100,
 validation_data=Xval,
 verbose=1)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# Model: "sequential_169"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_1 (Sequential)   (None, 64, 64, 3)         0
#
#  rescaling_170 (Rescaling)   (None, 64, 64, 3)         0
#
#  conv2d_835 (Conv2D)         (None, 64, 64, 16)        448
#
#  max_pooling2d_501 (MaxPooli  (None, 32, 32, 16)       0
#  ng2D)
#
#  conv2d_836 (Conv2D)         (None, 32, 32, 32)        4640
#
#  conv2d_837 (Conv2D)         (None, 32, 32, 32)        9248
#
#  max_pooling2d_502 (MaxPooli  (None, 16, 16, 32)       0
#  ng2D)
#
#  conv2d_838 (Conv2D)         (None, 16, 16, 64)        18496
#
#  conv2d_839 (Conv2D)         (None, 16, 16, 64)        36928
#
#  max_pooling2d_503 (MaxPooli  (None, 8, 8, 64)         0
#  ng2D)
#
#  dropout_167 (Dropout)       (None, 8, 8, 64)          0
#
#  flatten_167 (Flatten)       (None, 4096)              0
#
#  dense_501 (Dense)           (None, 128)               524416
#
#  dense_502 (Dense)           (None, 128)               16512
#
#  dense_503 (Dense)           (None, 5)                 645
#
# =================================================================
# Total params: 611,333
# Trainable params: 611,333
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 32/32 [==============================] - 28s 697ms/step - loss: 3.1869 - accuracy: 0.2000 - val_loss: 3.1021 - val_accuracy: 0.1940
# Epoch 2/100
# 32/32 [==============================] - 26s 793ms/step - loss: 3.0301 - accuracy: 0.2505 - val_loss: 2.9530 - val_accuracy: 0.1940
# Epoch 3/100
# 32/32 [==============================] - 27s 833ms/step - loss: 2.8854 - accuracy: 0.2485 - val_loss: 2.8140 - val_accuracy: 0.2700
# Epoch 4/100
# 32/32 [==============================] - 24s 724ms/step - loss: 2.7389 - accuracy: 0.3135 - val_loss: 2.6662 - val_accuracy: 0.3000
# Epoch 5/100
# 32/32 [==============================] - 24s 721ms/step - loss: 2.5681 - accuracy: 0.3645 - val_loss: 2.5351 - val_accuracy: 0.3000
# Epoch 6/100
# 32/32 [==============================] - 24s 722ms/step - loss: 2.4218 - accuracy: 0.3780 - val_loss: 2.4376 - val_accuracy: 0.2980
# Epoch 7/100
# 32/32 [==============================] - 24s 730ms/step - loss: 2.3084 - accuracy: 0.4065 - val_loss: 2.3345 - val_accuracy: 0.3420
# Epoch 8/100
# 32/32 [==============================] - 26s 801ms/step - loss: 2.1800 - accuracy: 0.4490 - val_loss: 2.2624 - val_accuracy: 0.3320
# Epoch 9/100
# 32/32 [==============================] - 26s 796ms/step - loss: 2.0862 - accuracy: 0.4810 - val_loss: 2.1703 - val_accuracy: 0.4000
# Epoch 10/100
# 32/32 [==============================] - 24s 720ms/step - loss: 1.9865 - accuracy: 0.5275 - val_loss: 2.0954 - val_accuracy: 0.4320
# Epoch 11/100
# Epoch 49/100
# 32/32 [==============================] - 23s 716ms/step - loss: 0.7499 - accuracy: 0.8770 - val_loss: 2.2552 - val_accuracy: 0.6960
# Epoch 50/100
# 32/32 [==============================] - 23s 716ms/step - loss: 0.7423 - accuracy: 0.8855 - val_loss: 2.1921 - val_accuracy: 0.6680
# Epoch 51/100
# 32/32 [==============================] - 23s 688ms/step - loss: 0.7267 - accuracy: 0.8870 - val_loss: 2.2468 - val_accuracy: 0.6740
# Epoch 52/100
# 32/32 [==============================] - 26s 785ms/step - loss: 0.6891 - accuracy: 0.9010 - val_loss: 2.3795 - val_accuracy: 0.7080
# Epoch 53/100
# 32/32 [==============================] - 23s 718ms/step - loss: 0.7038 - accuracy: 0.8915 - val_loss: 2.4822 - val_accuracy: 0.6260
# Epoch 54/100
# 32/32 [==============================] - 26s 805ms/step - loss: 0.7102 - accuracy: 0.8910 - val_loss: 2.3403 - val_accuracy: 0.6440
# Epoch 55/100
# 32/32 [==============================] - 23s 687ms/step - loss: 0.6624 - accuracy: 0.9135 - val_loss: 2.2603 - val_accuracy: 0.6940
# Epoch 56/100
# 32/32 [==============================] - 23s 715ms/step - loss: 0.6689 - accuracy: 0.9000 - val_loss: 2.3375 - val_accuracy: 0.6640
# Epoch 57/100
# 32/32 [==============================] - 23s 691ms/step - loss: 0.6738 - accuracy: 0.9020 - val_loss: 2.3921 - val_accuracy: 0.6680
# Epoch 58/100
# 32/32 [==============================] - 25s 759ms/step - loss: 0.6580 - accuracy: 0.9140 - val_loss: 2.4048 - val_accuracy: 0.7000
# Epoch 59/100
# 32/32 [==============================] - 25s 760ms/step - loss: 0.6801 - accuracy: 0.9040 - val_loss: 2.3922 - val_accuracy: 0.6460
# Epoch 60/100
# 32/32 [==============================] - 22s 681ms/step - loss: 0.6610 - accuracy: 0.9075 - val_loss: 2.3678 - val_accuracy: 0.6680
# Epoch 61/100
# 32/32 [==============================] - 24s 721ms/step - loss: 0.6372 - accuracy: 0.9105 - val_loss: 2.4588 - val_accuracy: 0.6320
# Epoch 62/100
# 32/32 [==============================] - 23s 717ms/step - loss: 0.6509 - accuracy: 0.9150 - val_loss: 2.4783 - val_accuracy: 0.6800
# Epoch 63/100
# 32/32 [==============================] - 24s 725ms/step - loss: 0.6243 - accuracy: 0.9215 - val_loss: 2.5509 - val_accuracy: 0.6540
# Epoch 64/100
# 32/32 [==============================] - 23s 684ms/step - loss: 0.6333 - accuracy: 0.9130 - val_loss: 2.6189 - val_accuracy: 0.5520
# Epoch 65/100
# 32/32 [==============================] - 24s 714ms/step - loss: 0.6488 - accuracy: 0.9210 - val_loss: 2.5342 - val_accuracy: 0.6520
# Epoch 66/100
# 32/32 [==============================] - 26s 789ms/step - loss: 0.6281 - accuracy: 0.9170 - val_loss: 2.7268 - val_accuracy: 0.6700
# Epoch 67/100
# 32/32 [==============================] - 26s 802ms/step - loss: 0.5974 - accuracy: 0.9305 - val_loss: 2.7662 - val_accuracy: 0.6860
# Epoch 68/100
# 32/32 [==============================] - 23s 714ms/step - loss: 0.6006 - accuracy: 0.9285 - val_loss: 2.7344 - val_accuracy: 0.6820
# Epoch 69/100
# 32/32 [==============================] - 27s 825ms/step - loss: 0.5829 - accuracy: 0.9260 - val_loss: 2.6133 - val_accuracy: 0.6960
# Epoch 70/100
# 32/32 [==============================] - 24s 719ms/step - loss: 0.5694 - accuracy: 0.9370 - val_loss: 2.9208 - val_accuracy: 0.6780
# Epoch 71/100
# 32/32 [==============================] - 25s 739ms/step - loss: 0.6034 - accuracy: 0.9315 - val_loss: 2.7437 - val_accuracy: 0.6500
# Epoch 72/100
# 32/32 [==============================] - 25s 773ms/step - loss: 0.5837 - accuracy: 0.9335 - val_loss: 2.7078 - val_accuracy: 0.6680
# Epoch 73/100
# 32/32 [==============================] - 24s 743ms/step - loss: 0.5790 - accuracy: 0.9350 - val_loss: 2.6965 - val_accuracy: 0.6540
# Epoch 74/100
# 32/32 [==============================] - 26s 809ms/step - loss: 0.5758 - accuracy: 0.9350 - val_loss: 2.8567 - val_accuracy: 0.6720
# Epoch 75/100
# 32/32 [==============================] - 24s 719ms/step - loss: 0.5513 - accuracy: 0.9470 - val_loss: 2.8580 - val_accuracy: 0.6680
# Epoch 76/100
# 32/32 [==============================] - 25s 751ms/step - loss: 0.5590 - accuracy: 0.9415 - val_loss: 3.2514 - val_accuracy: 0.6520
# Epoch 77/100
# 32/32 [==============================] - 26s 769ms/step - loss: 0.5591 - accuracy: 0.9345 - val_loss: 2.7720 - val_accuracy: 0.7020
# Epoch 78/100
# 32/32 [==============================] - 26s 786ms/step - loss: 0.5578 - accuracy: 0.9460 - val_loss: 2.6775 - val_accuracy: 0.6600
# Epoch 79/100
# 32/32 [==============================] - 24s 749ms/step - loss: 0.5433 - accuracy: 0.9465 - val_loss: 2.8195 - val_accuracy: 0.6700
# Epoch 80/100
# 32/32 [==============================] - 25s 755ms/step - loss: 0.5721 - accuracy: 0.9365 - val_loss: 2.7295 - val_accuracy: 0.6780
# Epoch 81/100
# 32/32 [==============================] - 25s 756ms/step - loss: 0.5592 - accuracy: 0.9350 - val_loss: 2.7514 - val_accuracy: 0.7020
# Epoch 82/100
# 32/32 [==============================] - 25s 774ms/step - loss: 0.5714 - accuracy: 0.9325 - val_loss: 2.9417 - val_accuracy: 0.6960
# Epoch 83/100
# 32/32 [==============================] - 24s 720ms/step - loss: 0.5268 - accuracy: 0.9500 - val_loss: 3.0425 - val_accuracy: 0.6880
# Epoch 84/100
# 32/32 [==============================] - 23s 717ms/step - loss: 0.5278 - accuracy: 0.9500 - val_loss: 3.1998 - val_accuracy: 0.6760
# Epoch 85/100
# 32/32 [==============================] - 24s 719ms/step - loss: 0.5351 - accuracy: 0.9430 - val_loss: 3.1711 - val_accuracy: 0.6700
# Epoch 86/100
# 32/32 [==============================] - 26s 810ms/step - loss: 0.5403 - accuracy: 0.9435 - val_loss: 3.1333 - val_accuracy: 0.6560
# Epoch 87/100
# 32/32 [==============================] - 22s 686ms/step - loss: 0.5510 - accuracy: 0.9405 - val_loss: 2.8400 - val_accuracy: 0.6300
# Epoch 88/100
# 32/32 [==============================] - 26s 770ms/step - loss: 0.5252 - accuracy: 0.9490 - val_loss: 3.1138 - val_accuracy: 0.6300
# Epoch 89/100
# 32/32 [==============================] - 24s 749ms/step - loss: 0.5362 - accuracy: 0.9465 - val_loss: 3.0137 - val_accuracy: 0.6000
# Epoch 90/100
# 32/32 [==============================] - 26s 787ms/step - loss: 0.5134 - accuracy: 0.9475 - val_loss: 2.8763 - val_accuracy: 0.6760
# Epoch 91/100
# 32/32 [==============================] - 28s 850ms/step - loss: 0.5026 - accuracy: 0.9575 - val_loss: 3.1792 - val_accuracy: 0.6620
# Epoch 92/100
# 32/32 [==============================] - 24s 718ms/step - loss: 0.5214 - accuracy: 0.9505 - val_loss: 3.0720 - val_accuracy: 0.6820
# Epoch 93/100
# 32/32 [==============================] - 24s 718ms/step - loss: 0.5118 - accuracy: 0.9470 - val_loss: 3.1893 - val_accuracy: 0.6640
# Epoch 94/100
# 32/32 [==============================] - 26s 804ms/step - loss: 0.5040 - accuracy: 0.9530 - val_loss: 3.1516 - val_accuracy: 0.6540
# Epoch 95/100
# 32/32 [==============================] - 25s 755ms/step - loss: 0.4814 - accuracy: 0.9600 - val_loss: 3.3191 - val_accuracy: 0.6520
# Epoch 96/100
# 32/32 [==============================] - 27s 841ms/step - loss: 0.4837 - accuracy: 0.9640 - val_loss: 3.3278 - val_accuracy: 0.6820
# Epoch 97/100
# 32/32 [==============================] - 24s 737ms/step - loss: 0.5009 - accuracy: 0.9540 - val_loss: 3.0180 - val_accuracy: 0.6840
# Epoch 98/100
# 32/32 [==============================] - 23s 716ms/step - loss: 0.4997 - accuracy: 0.9515 - val_loss: 3.2516 - val_accuracy: 0.6420
# Epoch 99/100
# 32/32 [==============================] - 23s 712ms/step - loss: 0.4813 - accuracy: 0.9630 - val_loss: 3.2943 - val_accuracy: 0.6740
# Epoch 100/100
# 32/32 [==============================] - 27s 817ms/step - loss: 0.4887 - accuracy: 0.9560 - val_loss: 3.0250 - val_accuracy: 0.6540

# %%
acc = history3.history['accuracy']
val_acc = history3.history['val_accuracy']
loss = history3.history['loss']
val_loss = history3.history['val_loss']
plt.figure()
plt.subplot(121)
plt.plot(acc)
plt.plot(val_acc)
plt.title('Accuracy')
plt.subplot(122)
plt.plot(loss)
plt.plot(val_loss)
plt.title('Loss')
plt.show()

# %%
labels = np.array([])
pred = np.array([])
for img, lab in Xtest:
    labels = np.append(labels, lab)
    pred = np.append(pred, np.argmax(model3.predict(img, verbose=0), axis=1))

# %%
from sklearn.metrics import accuracy_score
print('Tačnost modela na test skupu je: ' + str(100*accuracy_score(labels, pred)) + '%')
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(labels, pred, normalize='true')
cmDisplay = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=classes1)
cmDisplay.plot()
plt.show()
# Out:
# Tačnost modela na test skupu je: 20.599999999999998%
